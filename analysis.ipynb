# %%
import pandas as pd

# %%
file_path = 'data/default-cards-20230906090453.json'
df_all_sets= pd.read_json(file_path)

# %%
df_all_sets
# Out:
#       object                                    id  \
# 0       card  0000579f-7b35-4ed3-b44c-db2a538066fe
# 1       card  00006596-1166-4a79-8443-ca9f82e6db4e
# 2       card  0000a54c-a511-4925-92dc-01b937f9afad
# 3       card  0000cd57-91fe-411f-b798-646e965eec37
# 4       card  00012bd8-ed68-4978-a22d-f450c8a6e048
# ...      ...                                   ...
# 86648   card  fffcbc4e-c6dc-4808-b262-f7c453e74dd8
# 86649   card  fffce2f7-b619-4483-a75e-916343194641
# 86650   card  fffdf7f3-a230-417a-883a-069aabcbcca7
# 86651   card  fffe7b2b-22c3-4e6a-9b1b-c6d7b29b9f86
# 86652   card  ffff0825-9996-4ae5-90c8-cb976ccf4ae0
#
#                                   oracle_id multiverse_ids  mtgo_id  \
# 0      44623693-51d6-49ad-8cd7-140505caf02f       [109722]  25527.0
# 1      8ae3562f-28b7-4462-96ed-be0cf7052ccc       [189637]  34586.0
# 2      dc4e2134-f0c2-49aa-9ea3-ebf83af1445c             []      NaN
# 3      9f0d82ae-38bf-45d8-8cda-982b6ead1d72       [435231]  65170.0
# ...

# %%
df_all_sets.keys()
# Out:
# Index(['object', 'id', 'oracle_id', 'multiverse_ids', 'mtgo_id',
#        'mtgo_foil_id', 'tcgplayer_id', 'cardmarket_id', 'name', 'lang',
#        'released_at', 'uri', 'scryfall_uri', 'layout', 'highres_image',
#        'image_status', 'image_uris', 'mana_cost', 'cmc', 'type_line',
#        'oracle_text', 'power', 'toughness', 'colors', 'color_identity',
#        'keywords', 'legalities', 'games', 'reserved', 'foil', 'nonfoil',
#        'finishes', 'oversized', 'promo', 'reprint', 'variation', 'set_id',
#        'set', 'set_name', 'set_type', 'set_uri', 'set_search_uri',
#        'scryfall_set_uri', 'rulings_uri', 'prints_search_uri',
#        'collector_number', 'digital', 'rarity', 'flavor_text', 'card_back_id',
#        'artist', 'artist_ids', 'illustration_id', 'border_color', 'frame',
#        'full_art', 'textless', 'booster', 'story_spotlight', 'edhrec_rank',
#        'penny_rank', 'prices', 'related_uris', 'purchase_uris', 'all_parts',
# ...

# %%
df_woe = df_all_sets.query('set == "woe"')

# %%
df_woe
# Out:
#       object                                    id  \
# 5       card  0001e77a-7fff-49d2-a55c-42f6fdf6db08
# 48      card  00174be7-0dc8-43b9-81b6-f25a8c3fb4eb
# 439     card  01334fed-781e-4864-83fd-d37f787a778b
# 581     card  019b51b0-e5c6-4208-922b-7736686dddcd
# 732     card  0214ebc6-c59f-4170-8dd2-ce07caa6e6ad
# ...      ...                                   ...
# 86151   card  fe93ef82-51de-40ad-9b52-8f3fd11c144f
# 86292   card  fef34fc2-8d37-484d-9adf-e3bb70283f33
# 86319   card  ff065dbf-77e3-45a8-bcca-aff9eaeb151f
# 86504   card  ff857d41-767d-4e99-83cc-444738341b92
# 86563   card  ffb5786b-6825-4ebf-a1e1-80011340adbb
#
#                                   oracle_id multiverse_ids   mtgo_id  \
# 5      396b088d-f9af-4ee1-843f-dbe1633f9cc8             []  116428.0
# 48     180efbd4-0f77-41cc-8ae2-2e6ccf853d10             []  116290.0
# 439    dab16c93-9788-46e0-9345-838ebeda8d54             []  116364.0
# 581    c259e16f-2a44-4552-8678-815f757a02e8             []  116872.0
# ...

# %%
df_woe.object.unique()
# Out:
# array(['card'], dtype=object)

# %%
select_columns =    [
                    'name',
                    'uri',
                    'scryfall_uri',
                    'layout',
                    'mana_cost',
                    'cmc',
                    'type_line',
                    'oracle_text',
                    'power',
                    'toughness',
                    'colors',
                    'color_identity',
                    'keywords',
                    'set',
                    'set_name',
                    'scryfall_set_uri',
                    'rulings_uri',
                    'prints_search_uri',
                    'collector_number',
                    'rarity',
                    'flavor_text',
                    'artist',
                    'border_color',
                    'frame',
                    'full_art',
                    'textless',
                    'booster',
                    'story_spotlight',
                    'edhrec_rank',
                    'penny_rank',
                    'prices',
                    'all_parts',
                    'card_faces',
                    'preview', 
                    'produced_mana', 
                    'printed_name', 
                    'color_indicator',
                    'printed_type_line',
                    'printed_text',
                    ]

df_clean_woe = df_woe[select_columns]

# %%
df_clean_woe
# Out:
#                                          name  \
# 5       Obyra's Attendants // Desperate Parry
# 48                    Archon of the Wild Rose
# 439                            Tuinvale Guide
# 581                    Agatha's Soul Cauldron
# 732                     Stockpiling Celebrant
# ...                                       ...
# 86151                Goddric, Cloaked Reveler
# 86292                              Food Fight
# 86319                       Stormkeld Prowler
# 86504  Virtue of Strength // Garenbrig Growth
# 86563                    Ruby, Daring Tracker
#
#                                                      uri  \
# 5      https://api.scryfall.com/cards/0001e77a-7fff-4...
# 48     https://api.scryfall.com/cards/00174be7-0dc8-4...
# 439    https://api.scryfall.com/cards/01334fed-781e-4...
# 581    https://api.scryfall.com/cards/019b51b0-e5c6-4...
# 732    https://api.scryfall.com/cards/0214ebc6-c59f-4...
# ...                                                  ...
# ...

# %%
save_file_path = 'outputs/woe.csv'
df_clean_woe.to_csv(save_file_path)
